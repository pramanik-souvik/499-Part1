# %%
import pandas as pd

df = pd.read_csv('merged_data.csv')
df.head()
# Out:
#   type                               content
# 0   h1           অনুশীলন সমিতি - উইকিপিডিয়া
# 1    p           অনুশীলন সমিতি - উইকিপিডিয়া
# 2    p                     বিষয়বস্তুতে চলুন
# 3    p                           প্রধান মেনু
# 4    p  প্রধান মেনু\nপার্শ্বদণ্ডে নিন\nলুকান

# %%
df = pd.read_csv('cleaned_dataset.csv')
df.head()
# Out:
#   type                             content
# 0   h1         অনুশীলন সমিতি - উইকিপিডিয়া
# 1    p         অনুশীলন সমিতি - উইকিপিডিয়া
# 2    p                   বিষয়বস্তুতে চলুন
# 3    p                         প্রধান মেনু
# 4    p  প্রধান মেনু পার্শ্বদণ্ডে নিন লুকান

# %%
df = pd.read_csv('processed_output.csv')
df.head()
# Out:
#   type                                            content  \
# 0    p  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1    p  সংযোগকারী পৃষ্ঠাসমূহসম্পর্কিত পরিবর্তনআপলোড কর...
# 2    p  অনুশীলন সমিতিনীতিবাক্যব্রিটিশ তাড়াওগঠিত২৪ মার...
# 3    p  অনুশীলন সমিতি তালিকা অরবিন্দ ঘোষ প্রমথনাথ মিত্...
# 4    p  উল্লেখযোগ্য ঘটনা তালিকা আলিপুর বোমা মামলা হাওড...
#
#                                                title  \
# 0  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1  সংযোগকারী পৃষ্ঠাসমূহসম্পর্কিত পরিবর্তনআপলোড কর...
# 2  অনুশীলন সমিতিনীতিবাক্যব্রিটিশ তাড়াওগঠিত২৪ মার...
# 3  অনুশীলন সমিতি তালিকা অরবিন্দ ঘোষ প্রমথনাথ মিত্...
# 4  উল্লেখযোগ্য ঘটনা তালিকা আলিপুর বোমা মামলা হাওড...
#
#                                              passage
# 0  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1  সংযোগকারী পৃষ্ঠাসমূহসম্পর্কিত পরিবর্তনআপলোড কর...
# 2  অনুশীলন সমিতিনীতিবাক্যব্রিটিশ তাড়াওগঠিত২৪ মার...
# 3  অনুশীলন সমিতি তালিকা অরবিন্দ ঘোষ প্রমথনাথ মিত্...
# 4  উল্লেখযোগ্য ঘটনা তালিকা আলিপুর বোমা মামলা হাওড...

# %%
df = pd.read_csv('processed_output1.csv')
df.head()
# Out:
#   type                                            content  \
# 0    p  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1    p  সংযোগকারী পৃষ্ঠাসমূহসম্পর্কিত পরিবর্তনআপলোড কর...
# 2    p  অনুশীলন সমিতিনীতিবাক্যব্রিটিশ তাড়াওগঠিত২৪ মার...
# 3    p  অনুশীলন সমিতি তালিকা অরবিন্দ ঘোষ প্রমথনাথ মিত্...
# 4    p  উল্লেখযোগ্য ঘটনা তালিকা আলিপুর বোমা মামলা হাওড...
#
#                                                title  \
# 0  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1  সংযোগকারী পৃষ্ঠাসমূহসম্পর্কিত পরিবর্তনআপলোড কর...
# 2  অনুশীলন সমিতিনীতিবাক্যব্রিটিশ তাড়াওগঠিত২৪ মার...
# 3  অনুশীলন সমিতি তালিকা অরবিন্দ ঘোষ প্রমথনাথ মিত্...
# 4  উল্লেখযোগ্য ঘটনা তালিকা আলিপুর বোমা মামলা হাওড...
#
#                                              passage
# 0  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1  সংযোগকারী পৃষ্ঠাসমূহসম্পর্কিত পরিবর্তনআপলোড কর...
# 2  অনুশীলন সমিতিনীতিবাক্যব্রিটিশ তাড়াওগঠিত২৪ মার...
# 3  অনুশীলন সমিতি তালিকা অরবিন্দ ঘোষ প্রমথনাথ মিত্...
# 4  উল্লেখযোগ্য ঘটনা তালিকা আলিপুর বোমা মামলা হাওড...

# %%
df = pd.read_csv('processed.csv')
df.head()
# Out:
#   type                                            content  __index_level_0__  \
# 0    p  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...                  7
# 1    p  সংযোগকারী পৃষ্ঠাসমূহসম্পর্কিত পরিবর্তনআপলোড কর...                 42
# 2    p  অনুশীলন সমিতিনীতিবাক্যব্রিটিশ তাড়াওগঠিত২৪ মার...                 51
# 3    p  অনুশীলন সমিতি\nতালিকা\nঅরবিন্দ ঘোষ\nপ্রমথনাথ ম...                 52
# 4    p  উল্লেখযোগ্য ঘটনা\nতালিকা\nআলিপুর বোমা মামলা\nহ...                 53
#
#                                              passage  \
# 0  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1  সংযোগকারী পৃষ্ঠাসমূহসম্পর্কিত পরিবর্তনআপলোড কর...
# 2  অনুশীলন সমিতিনীতিবাক্যব্রিটিশ তাড়াওগঠিত২৪ মার...
# 3  অনুশীলন সমিতি\nতালিকা\nঅরবিন্দ ঘোষ\nপ্রমথনাথ ম...
# 4  উল্লেখযোগ্য ঘটনা\nতালিকা\nআলিপুর বোমা মামলা\nহ...
#
#                                                title
# 0  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1  সংযোগকারী পৃষ্ঠাসমূহসম্পর্কিত পরিবর্তনআপলোড কর...
# 2  অনুশীলন সমিতিনীতিবাক্যব্রিটিশ তাড়াওগঠিত২৪ মার...
# 3  অনুশীলন সমিতি\nতালিকা\nঅরবিন্দ ঘোষ\nপ্রমথনাথ ম...
# 4  উল্লেখযোগ্য ঘটনা\nতালিকা\nআলিপুর বোমা মামলা\nহ...

# %%
df = pd.read_csv('bengali_history_qa_dataset.csv')
print(df)
# Out:
#          id                                     original_title  \
# 0         1  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1         1  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 2         1  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 3         1  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 4         1  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# ...     ...                                                ...
# 28405  5682  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28406  5682  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28407  5682  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28408  5682  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28409  5682  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
#
#                                              source_text  \
# 0      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 2      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 3      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 4      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# ...                                                  ...
# 28405  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28406  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28407  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28408  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28409  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
#
#                                         question  \
# 0                    এই লেখার মূল বিষয়বস্তু কী?
# 1        এতে কী ঐতিহাসিক ঘটনা বর্ণনা করা হয়েছে?
# 2           লেখাটি কোন সময়কাল নিয়ে আলোচনা করে?
# 3      এতে উল্লেখযোগ্য ব্যক্তি বা ঘটনাবলি কী কী?
# 4                          এর প্রেক্ষাপট কী ছিল?
# ...                                          ...
# 28405                এই লেখার মূল বিষয়বস্তু কী?
# 28406    এতে কী ঐতিহাসিক ঘটনা বর্ণনা করা হয়েছে?
# 28407       লেখাটি কোন সময়কাল নিয়ে আলোচনা করে?
# 28408  এতে উল্লেখযোগ্য ব্যক্তি বা ঘটনাবলি কী কী?
# 28409                      এর প্রেক্ষাপট কী ছিল?
#
#                                                   answer
# 0      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 2      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 3      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 4      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# ...                                                  ...
# 28405  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28406  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28407  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28408  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28409  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
#
# [28410 rows x 5 columns]

# %%
df = pd.read_csv('Dataset.csv')
print(df)
# Out:
#                                           original_title  \
# 0      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 2      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 3      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 4      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# ...                                                  ...
# 28405  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28406  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28407  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28408  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28409  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
#
#                                              source_text  \
# 0      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 2      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 3      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 4      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# ...                                                  ...
# 28405  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28406  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28407  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28408  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28409  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
#
#                                         question  \
# 0                    এই লেখার মূল বিষয়বস্তু কী?
# 1        এতে কী ঐতিহাসিক ঘটনা বর্ণনা করা হয়েছে?
# 2           লেখাটি কোন সময়কাল নিয়ে আলোচনা করে?
# 3      এতে উল্লেখযোগ্য ব্যক্তি বা ঘটনাবলি কী কী?
# 4                          এর প্রেক্ষাপট কী ছিল?
# ...                                          ...
# 28405                এই লেখার মূল বিষয়বস্তু কী?
# 28406    এতে কী ঐতিহাসিক ঘটনা বর্ণনা করা হয়েছে?
# 28407       লেখাটি কোন সময়কাল নিয়ে আলোচনা করে?
# 28408  এতে উল্লেখযোগ্য ব্যক্তি বা ঘটনাবলি কী কী?
# 28409                      এর প্রেক্ষাপট কী ছিল?
#
#                                                   answer
# 0      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 2      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 3      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 4      প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# ...                                                  ...
# 28405  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28406  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28407  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28408  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
# 28409  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
#
# [28410 rows x 4 columns]

# %%
df = pd.read_csv('bengali_history_qa_dataset_llm.csv')
print(df)
# Out:
#         id                                     original_title  \
# 0        1  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1        2  সংযোগকারী পৃষ্ঠাসমূহসম্পর্কিত পরিবর্তনআপলোড কর...
# 2        3  অনুশীলন সমিতিনীতিবাক্যব্রিটিশ তাড়াওগঠিত২৪ মার...
# 3        4  অনুশীলন সমিতি তালিকা অরবিন্দ ঘোষ প্রমথনাথ মিত্...
# 4        5  উল্লেখযোগ্য ঘটনা তালিকা আলিপুর বোমা মামলা হাওড...
# ...    ...                                                ...
# 5677  5678  ↑ "জাবালে নূর বাস মালিকের হাইকোর্টে জামিন"। কা...
# 5678  5679  বহিঃসংযোগ[সম্পাদনা] নিরাপদ সড়ক আন্দোলনের বিশদ...
# 5679  5680  ইউটিউবে Students take to streets for 7th day, ...
# 5680  5681  এ পৃষ্ঠায় শেষ পরিবর্তন হয়েছিল ০২:১৯টার সময়,...
# 5681  5682  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
#
#                                             source_text  \
# 0     প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1     সংযোগকারী পৃষ্ঠাসমূহসম্পর্কিত পরিবর্তনআপলোড কর...
# 2     অনুশীলন সমিতিনীতিবাক্যব্রিটিশ তাড়াওগঠিত২৪ মার...
# 3     অনুশীলন সমিতি তালিকা অরবিন্দ ঘোষ প্রমথনাথ মিত্...
# 4     উল্লেখযোগ্য ঘটনা তালিকা আলিপুর বোমা মামলা হাওড...
# ...                                                 ...
# 5677  ↑ "জাবালে নূর বাস মালিকের হাইকোর্টে জামিন"। কা...
# 5678  বহিঃসংযোগ[সম্পাদনা] নিরাপদ সড়ক আন্দোলনের বিশদ...
# 5679  ইউটিউবে Students take to streets for 7th day, ...
# 5680  এ পৃষ্ঠায় শেষ পরিবর্তন হয়েছিল ০২:১৯টার সময়,...
# 5681  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
#
#                                                question  \
# 0     নিচের টেক্সটের উপর ভিত্তি করে একটি প্রশ্নভিত্ত...
# 1     নীচের টেক্সটের উপর ভিত্তি করে একটি প্রশ্ন ভিত্...
# 2     অনুশীলন সমিতির প্রভাব তালিকা ভারতীয় জাতীয়তাব...
# 3     নিচের পাঠ্যাংশের উপর ভিত্তি করে অনুশীলন সমিতি ...
# 4     নিচের পাঠ্যাংশের উপর ভিত্তি করে একটি প্রশ্নভিত...
# ...                                                 ...
# 5677  নিচের পাঠ্যাংশের উপর ভিত্তি করে একটি প্রশ্ন:  ...
# 5678  নীচের টেক্সটের উপর ভিত্তি করে একটি প্রশ্ন নিচে...
# 5679  ইউটিউবে শেখ হাসিনার প্রধানমন্ত্রিত্বের উপর ভিত...
# 5680  এই পোস্টের উপর ভিত্তি করে একটি প্রশ্ন ভিত্তিক ...
# 5681  নিচের টেক্সটের উপর ভিত্তি করে একটি প্রশ্ন ভিত্...
#
#                                                  answer
# 0     প্রশ্ন: নিচের টেক্সটের উপর ভিত্তি করে একটি প্র...
# 1     প্রশ্ন: নিম্নলিখিত টেক্সটের উপর ভিত্তি করে একট...
# 2     অনুশীলন সমিতির প্রভাব তালিকা ভারতীয় জাতীয়তাব...
# 3     নিচের পাঠ্যাংশের উপর ভিত্তি করে অনুশীলন সমিতিগ...
# 4     প্রশ্ন: নিচের পাঠ্যাংশের উপর ভিত্তি করে একটি প...
# ...                                                 ...
# 5677  উত্তর: নীচের শাস্ত্রপদটির উপর ভিত্তি করে একটি ...
# 5678  উত্তর: নীচের টেক্সটের উপর ভিত্তি করে একটি প্রশ...
# 5679  ইউটিউবে শেখ হাসিনার প্রধানমন্ত্রিত্বের উপর ভিত...
# 5680  উত্তর: এই পোস্টের উপর ভিত্তি করে একটি প্রশ্ন-ভ...
# 5681  উত্তর: নিচের টেক্সটের উপর ভিত্তি করে একটি প্রশ...
#
# [5682 rows x 5 columns]

# %%
import pandas as pd

df = pd.read_json('data.json')
print(df)
# Out:
#         ﻿id                                     original_title  \
# 0       1.0  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1       1.0  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 2       1.0  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 3       1.0  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 4       1.0  প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# ...     ...                                                ...
# 101351
# 101352
# 101353
# 101354
# 101355
#
#                                               source_text  \
# 0       প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1       প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 2       প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 3       প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 4       প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# ...                                                   ...
# 101351
# 101352
# 101353
# 101354
# 101355
#
#                                          question  \
# 0                     এই লেখার মূল বিষয়বস্তু কী?
# 1         এতে কী ঐতিহাসিক ঘটনা বর্ণনা করা হয়েছে?
# 2            লেখাটি কোন সময়কাল নিয়ে আলোচনা করে?
# 3       এতে উল্লেখযোগ্য ব্যক্তি বা ঘটনাবলি কী কী?
# 4                           এর প্রেক্ষাপট কী ছিল?
# ...                                           ...
# 101351
# 101352
# 101353
# 101354
# 101355
#
#                                                    answer type  \
# 0       প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 1       প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 2       প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 3       প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# 4       প্রধান পাতাসম্প্রদায়ের প্রবেশদ্বারসম্প্রদায়ে...
# ...                                                   ...  ...
# 101351                                                       p
# 101352                                                       p
# 101353                                                       p
# 101354                                                       p
# 101355                                                       p
#
#                                                   content __index_level_0__  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...               ...
# 101351  ↑ "জাবালে নূর বাস মালিকের হাইকোর্টে জামিন"। কা...
# 101352  বহিঃসংযোগ[সম্পাদনা] নিরাপদ সড়ক আন্দোলনের বিশদ...
# 101353  ইউটিউবে Students take to streets for 7th day, ...
# 101354  এ পৃষ্ঠায় শেষ পরিবর্তন হয়েছিল ০২:১৯টার সময়,...
# 101355  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
#
#                                                   passage  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 101351  ↑ "জাবালে নূর বাস মালিকের হাইকোর্টে জামিন"। কা...
# 101352  বহিঃসংযোগ[সম্পাদনা] নিরাপদ সড়ক আন্দোলনের বিশদ...
# 101353  ইউটিউবে Students take to streets for 7th day, ...
# 101354  এ পৃষ্ঠায় শেষ পরিবর্তন হয়েছিল ০২:১৯টার সময়,...
# 101355  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
#
#                                                     title
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 101351  ↑ "জাবালে নূর বাস মালিকের হাইকোর্টে জামিন"। কা...
# 101352  বহিঃসংযোগ[সম্পাদনা] নিরাপদ সড়ক আন্দোলনের বিশদ...
# 101353  ইউটিউবে Students take to streets for 7th day, ...
# 101354  এ পৃষ্ঠায় শেষ পরিবর্তন হয়েছিল ০২:১৯টার সময়,...
# 101355  গোপনীয়তার নীতি উইকিপিডিয়া বৃত্তান্ত দাবিত্যা...
#
# [101356 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# id                  0
# original_title       0
# source_text          0
# question             0
# answer               0
# type                 0
# content              0
# __index_level_0__    0
# passage              0
# title                0
# dtype: int64
